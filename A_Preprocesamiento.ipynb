# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelicaCeDi/Analitica-3-caso-salud/blob/main/A_Preprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTAR PAQUETES
import pandas as pd
import sqlite3 as sql

# %%
url='https://raw.githubusercontent.com/AngelicaCeDi/Analitica-3-caso-salud/main/brain_stroke.csv'
stroke=pd.read_csv(url ,sep=',')
stroke.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
# !git clone "https://github.com/AngelicaCeDi/Analitica-3-Caso-salud.git"
# Out:
# Cloning into 'Analitica-3-Caso-salud'...
# remote: Enumerating objects: 57, done.
# remote: Total 57 (delta 0), reused 0 (delta 0), pack-reused 57
# Unpacking objects: 100% (57/57), 1.50 MiB | 1.30 MiB/s, done.

# %%
import os
path="/content/Analitica-3-Caso-salud"
os.chdir(path)
os.listdir(path)
# Out:
# ['DISEÑO DE SOLUCIÓN.png',
#  'brain_stroke.csv',
#  'strokeb.db',
#  '.git',
#  'Brainfunciones.py',
#  'README.md']

# %%
# !python Brainfunciones.py

# %%
import Brainfunciones as bf 
#Exploración
bf.report_data(stroke) # Reporte de los datos y sus características.
# Out:
# Dimensiones
# (4981, 11)
# -------------------------------------------------
# Formatos de variables
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object
# -------------------------------------------------
# Nulos
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64
# -------------------------------------------------
# Duplicados
# 0
# -------------------------------------------------
# Variables Númericas
# ...

# %%
#Volvemos algunas variables que nos interesan binarias
#La variable gender.
bf.get_binary(stroke,'gender','Male','Female')
# Out:
# Ya es una columna binaria

# %%
#la variable ever_married.
bf.get_binary(stroke,'ever_married','Yes','No')
# Out:
# Ya es una columna binaria

# %%
# Y la variable Residence_type.
bf.get_binary(stroke,'Residence_type','Urban','Rural')
# Out:
# Ya es una columna binaria

# %%
stroke
# Out:
#       gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0          1  67.0             0              1             1        Private
# 1          1  80.0             0              1             1        Private
# 2          0  49.0             0              0             1        Private
# 3          0  79.0             1              0             1  Self-employed
# 4          1  81.0             0              0             1        Private
# ...      ...   ...           ...            ...           ...            ...
# 4976       1  41.0             0              0             0        Private
# 4977       1  40.0             0              0             1        Private
# 4978       0  45.0             1              0             1       Govt_job
# 4979       1  40.0             0              0             1        Private
# 4980       0  80.0             1              0             1        Private
#
# ...

# %%
#Crear base de datos sql
conn=sql.connect("strokeb.db")

# %%
#Guardando la tabla en la base de datos de strokeb
stroke.to_sql("stroke",conn,if_exists="replace")
# Out:
# 4981
